# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/employement-arick-repo/blob/main/Vivo_Ignite_1_Exploring_Indian_Disability_and_Employment_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EDA insights :  Exploring Indian Disability and Employment Data##Questionnaire for employees
#  **(1) Demographic and Employment Analysis**<br>
#  **(2) Mental Health and Employment Correlation**<br>
#  **(3) Financial and Social Welfare Insights**<br>
#  **(4) Workplace and Psychological Well-being**<br>
#
#  ### Author : Arick Agarwal

# %% [markdown]
# # Step 1: Mount Google Drive

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Step 2: Specify the file path for the CSV file in your Google Drive

# %%
# Step 2: Specify the file path for the CSV file in your Google Drive
file_path = '/content/drive/MyDrive/1.ALL-RESEARCH/ARICK AGARWAL/DATASET/FINAL-Questionnaire-Form-Responses.csv'

# %% [markdown]
# # Step 3: Import necessary libraries

# %%
# Step 3: Import necessary libraries
import pandas as pd

# %% [markdown]
# # Step 4: Load the CSV file into a Pandas DataFrame

# %%
# Step 4: Load the CSV file into a Pandas DataFrame
try:
    df = pd.read_csv(file_path)
    print("CSV file loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please check the file path.")
# Out:
# CSV file loaded successfully!

# %% [markdown]
# # Step 5: Display the first few rows of the DataFrame

# %%
# Step 5: Display the first few rows of the DataFrame
print("\nPreview of the DataFrame:")
print(df.head())
# Out:
# Preview of the DataFrame:
#             Timestamp                                     Email  \
# 0  1/24/2025 18:11:32                    arickagarwal@gmail.com
# 1  1/28/2025 14:11:32  radhakrishnanrajan@onmyowntechnology.com
# 2  1/28/2025 14:13:31         surajsharma@onmyowntechnology.com
# 3  1/28/2025 14:17:21         priyamishra@onmyowntechnology.com
# 4  1/28/2025 14:19:23      kashishagarwal@onmyowntechnology.com
#
#   Name of the Participant Participant Age Range Participant gender  \
# 0           arick agarwal                  < 18               Male
# 1     Radhakrishnan Rajan               30 - 50               Male
# 2            Suraj Sharma               30 - 50               Male
# 3            Priya Mishra               19 - 30             Female
# 4         Kashish Agarwal               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  \
# 0            Technician                     1â€“5 years
# 1               Laborer                    6â€“10 years
# 2            Technician                     1â€“5 years
# 3            Technician                     1â€“5 years
# 4            Technician                     1â€“5 years
#
#   1. Which among the below categories best explains your status?  ...  \
# 0                    In-Seeing (Visual Disabilities)              ...
# 1                In-Movement (Mobility Disabilities)              ...
# 2     Mental Retardation (Intellectual Disabilities)              ...
# 3                  In-Hearing (Hearing Disabilities)              ...
# 4                    In-Speech (Speech Disabilities)              ...
#
#   11. Do you engage in reading outside of work or school?  \
# 0                                  Yes, occasionally
# 1                                             Rarely
# 2                                             Rarely
# 3                                  Yes, occasionally
# 4                                  Yes, occasionally
#
#   12. Do you receive food stamps or similar social welfare benefits?  \
# 0                                  Yes, occasionally
# 1                                  Yes, occasionally
# 2                              No, I am not eligible
# 3                                  Yes, occasionally
# 4                                  Yes, occasionally
#
#   13. How many times have you been hospitalized for mental illness?  \
# 0                                                NaN
# 1                                                NaN
# 2                                        1â€“2 times
# 3                                        3â€“5 times
# 4                                        1â€“2 times
#
#   14. How often do you experience a lack of concentration?  \
# 0                 Rarely, during high-stress periods
# 1                       Occasionally, but manageable
# 2                       Occasionally, but manageable
# 3             Frequently, affecting daily activities
# 4                       Occasionally, but manageable
#
#                15. Do you experience anxiety?  \
# 0                Occasionally, but manageable
# 1                Occasionally, but manageable
# 2                Occasionally, but manageable
# 3  Frequently, requiring professional support
# 4                Occasionally, but manageable
#
#       16. How often do you experience depression?  \
# 0                                          Rarely
# 1                                          Rarely
# 2  Occasionally, but manageable without treatment
# 3     Frequently, requiring medication or therapy
# 4  Occasionally, but manageable without treatment
#
#           17. Do you engage in obsessive thinking?  \
# 0                          Rarely, not significant
# 1                          Rarely, not significant
# 2                        Yes, but it is manageable
# 3  Yes, and it significantly impacts my daily life
# 4                        Yes, but it is manageable
#
#   18. How often do you experience mood swings?  \
# 0                                      Monthly
# 1                                      Monthly
# 2                                       Weekly
# 3                                        Daily
# 4                                       Weekly
#
#   19. Do you experience panic attacks?  \
# 0                    Yes, occasionally
# 1                    Yes, occasionally
# 2                    Yes, occasionally
# 3                      Yes, frequently
# 4                    Yes, occasionally
#
#   20. How often do you engage in compulsive behavior?
# 0                                             Rarely
# 1                       Occasionally, but manageable
# 2                       Occasionally, but manageable
# 3         Frequently, requiring professional support
# 4                       Occasionally, but manageable
#
# [5 rows x 29 columns]

# %% [markdown]
# # Step 6: Perform 10 Pandas Functions

# %%
# Step 6: Perform 10 Pandas Functions

# %%
# Function 1: Display DataFrame information
print("\nDataFrame Information:")
df.info()
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 29 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   Timestamp                                                                           21 non-null     object
#  1   Email                                                                               21 non-null     object
#  2   Name of the Participant                                                             21 non-null     object
#  3   Participant Age Range                                                               21 non-null     object
#  4   Participant gender                                                                  21 non-null     object
#  5   Participant region of work                                                          21 non-null     object
#  6   Participant industry of work                                                        21 non-null     object
#  7   Participant  job role                                                               21 non-null     object
#  8   Participant years of experience                                                     21 non-null     object
#  9   1. Which among the below categories best explains your status?                      20 non-null     object
#  10  2. Are you currently employed at least part-time?                                   21 non-null     object
#  11  3. Do you identify as having a mental illness?                                      21 non-null     object
#  12  4. Do you have access to a personal computer separate from a smartphone?            21 non-null     object
#  13  5. Have you been hospitalised before for a mental illness?                          21 non-null     object
#  14  6. If hospitalised for mental illness, how many days were you hospitalised?         21 non-null     object
#  15  7. Do you have regular access to the internet?                                      21 non-null     object
#  16  8. Have you experienced any gaps in your resume due to health or other reasons?     21 non-null     object
#  17  9. What is your monthly income, including any social welfare programs, in INR â‚¹?  21 non-null     object
#  18  10. Are you currently unemployed?                                                   21 non-null     object
#  19  11. Do you engage in reading outside of work or school?                             21 non-null     object
#  20  12. Do you receive food stamps or similar social welfare benefits?                  21 non-null     object
#  21  13. How many times have you been hospitalized for mental illness?                   5 non-null      object
#  22  14. How often do you experience a lack of concentration?                            21 non-null     object
#  23  15. Do you experience anxiety?                                                      21 non-null     object
#  24  16. How often do you experience depression?                                         21 non-null     object
#  25  17. Do you engage in obsessive thinking?                                            21 non-null     object
#  26  18. How often do you experience mood swings?                                        21 non-null     object
#  27  19. Do you experience panic attacks?                                                21 non-null     object
#  28  20. How often do you engage in compulsive behavior?                                 21 non-null     object
# dtypes: object(29)
# memory usage: 4.9+ KB

# %%
# Function 2: Get statistical summary
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#                  Timestamp                   Email Name of the Participant  \
# count                   21                      21                      21
# unique                  20                      21                      21
# top     1/28/2025 18:48:00  arickagarwal@gmail.com           arick agarwal
# freq                     2                       1                       1
#
#        Participant Age Range Participant gender Participant region of work  \
# count                     21                 21                         21
# unique                     4                  2                          2
# top                  19 - 30               Male                      Urban
# freq                      11                 19                         17
#
#        Participant industry of work Participant  job role  \
# count                            21                    21
# unique                            4                     4
# top                        Services                 Other
# freq                             13                     9
#
#        Participant years of experience  \
# count                               21
# unique                               4
# top                        1â€“5 years
# freq                                10
#
#        1. Which among the below categories best explains your status?  ...  \
# count                                                  20              ...
# unique                                                  5              ...
# top                   In-Movement (Mobility Disabilities)              ...
# freq                                                    9              ...
#
#        11. Do you engage in reading outside of work or school?  \
# count                                                  21
# unique                                                  4
# top                                     Yes, occasionally
# freq                                                    9
#
#        12. Do you receive food stamps or similar social welfare benefits?  \
# count                                                  21
# unique                                                  6
# top                                 No, I am not eligible
# freq                                                    9
#
#        13. How many times have you been hospitalized for mental illness?  \
# count                                                   5
# unique                                                  2
# top                                           1â€“2 times
# freq                                                    4
#
#        14. How often do you experience a lack of concentration?  \
# count                                                  21
# unique                                                  4
# top                           Never / Not experienced yet
# freq                                                    9
#
#        15. Do you experience anxiety?  \
# count                              21
# unique                              4
# top      Occasionally, but manageable
# freq                                9
#
#        16. How often do you experience depression?  \
# count                                           21
# unique                                           4
# top                 I do not experience depression
# freq                                            10
#
#        17. Do you engage in obsessive thinking?  \
# count                                        21
# unique                                        4
# top                   Yes, but it is manageable
# freq                                          6
#
#        18. How often do you experience mood swings?  \
# count                                            21
# unique                                            5
# top                                           Never
# freq                                              7
#
#        19. Do you experience panic attacks?  \
# count                                    21
# unique                                    4
# top                                      No
# freq                                     13
#
#        20. How often do you engage in compulsive behavior?
# count                                                  21
# unique                                                  5
# top                          Occasionally, but manageable
# freq                                                    7
#
# [4 rows x 29 columns]

# %%
# Function 3: Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Timestamp                                                                              0
# Email                                                                                  0
# Name of the Participant                                                                0
# Participant Age Range                                                                  0
# Participant gender                                                                     0
# Participant region of work                                                             0
# Participant industry of work                                                           0
# Participant  job role                                                                  0
# Participant years of experience                                                        0
# 1. Which among the below categories best explains your status?                         1
# 2. Are you currently employed at least part-time?                                      0
# 3. Do you identify as having a mental illness?                                         0
# 4. Do you have access to a personal computer separate from a smartphone?               0
# 5. Have you been hospitalised before for a mental illness?                             0
# 6. If hospitalised for mental illness, how many days were you hospitalised?            0
# 7. Do you have regular access to the internet?                                         0
# 8. Have you experienced any gaps in your resume due to health or other reasons?        0
# 9. What is your monthly income, including any social welfare programs, in INR â‚¹?     0
# 10. Are you currently unemployed?                                                      0
# 11. Do you engage in reading outside of work or school?                                0
# 12. Do you receive food stamps or similar social welfare benefits?                     0
# 13. How many times have you been hospitalized for mental illness?                     16
# 14. How often do you experience a lack of concentration?                               0
# 15. Do you experience anxiety?                                                         0
# 16. How often do you experience depression?                                            0
# 17. Do you engage in obsessive thinking?                                               0
# 18. How often do you experience mood swings?                                           0
# 19. Do you experience panic attacks?                                                   0
# 20. How often do you engage in compulsive behavior?                                    0
# dtype: int64

# %%
# Function 4: Display column names
print("\nColumn Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Timestamp', 'Email', 'Name of the Participant',
#        'Participant Age Range', 'Participant gender',
#        'Participant region of work', 'Participant industry of work',
#        'Participant  job role', 'Participant years of experience',
#        '1. Which among the below categories best explains your status?',
#        '2. Are you currently employed at least part-time?',
#        '3. Do you identify as having a mental illness?',
#        '4. Do you have access to a personal computer separate from a smartphone?',
#        '5. Have you been hospitalised before for a mental illness?',
#        '6. If hospitalised for mental illness, how many days were you hospitalised?',
#        '7. Do you have regular access to the internet?',
#        '8. Have you experienced any gaps in your resume due to health or other reasons?',
#        '9. What is your monthly income, including any social welfare programs, in INR â‚¹?',
#        '10. Are you currently unemployed?',
#        '11. Do you engage in reading outside of work or school?',
#        '12. Do you receive food stamps or similar social welfare benefits?',
#        '13. How many times have you been hospitalized for mental illness?',
#        '14. How often do you experience a lack of concentration?',
#        '15. Do you experience anxiety?',
#        '16. How often do you experience depression?',
#        '17. Do you engage in obsessive thinking?',
#        '18. How often do you experience mood swings?',
#        '19. Do you experience panic attacks?',
#        '20. How often do you engage in compulsive behavior?'],
#       dtype='object')

# %%
# Function 5: Display shape of the DataFrame
print("\nShape of the DataFrame (Rows, Columns):")
print(df.shape)
# Out:
# Shape of the DataFrame (Rows, Columns):
# (21, 29)

# %%
# Function 6: Get unique values from a specific column
column_name = 'Participant gender'  # Replace with an actual column name from your DataFrame
if column_name in df.columns:
    print(f"\nUnique values in column '{column_name}':")
    print(df[column_name].unique())
else:
    print(f"\nColumn '{column_name}' not found in the DataFrame.")
# Out:
# Unique values in column 'Participant gender':
# ['Male' 'Female']

# %%
# Function 7: Sort the DataFrame by a specific column
sort_column = 'Participant gender'  # Replace with an actual column name from your DataFrame
if sort_column in df.columns:
    sorted_df = df.sort_values(by=sort_column, ascending=True)
    print(f"\nDataFrame sorted by '{sort_column}':")
    print(sorted_df.head())
else:
    print(f"\nColumn '{sort_column}' not found in the DataFrame.")
# Out:
# DataFrame sorted by 'Participant gender':
#              Timestamp                                 Email  \
# 3   1/28/2025 14:17:21     priyamishra@onmyowntechnology.com
# 4   1/28/2025 14:19:23  kashishagarwal@onmyowntechnology.com
# 0   1/24/2025 18:11:32                arickagarwal@gmail.com
# 18  1/29/2025 22:16:31            prabhat.rajput16@gmail.com
# 17  1/29/2025 21:51:58            singh.lokesh1206@gmail.com
#
#    Name of the Participant Participant Age Range Participant gender  \
# 3             Priya Mishra               19 - 30             Female
# 4          Kashish Agarwal               19 - 30             Female
# 0            arick agarwal                  < 18               Male
# 18           Prabhat Singh               19 - 30               Male
# 17            Lokesh Kumar               19 - 30               Male
#
#    Participant region of work Participant industry of work  \
# 3                       Urban                     Services
# 4                       Rural                Manufacturing
# 0                       Urban                Manufacturing
# 18                      Urban                        Other
# 17                      Urban                     Services
#
#    Participant  job role Participant years of experience  \
# 3             Technician                     1â€“5 years
# 4             Technician                     1â€“5 years
# 0             Technician                     1â€“5 years
# 18                 Other                Less than 1 year
# 17               Manager                     1â€“5 years
#
#    1. Which among the below categories best explains your status?  ...  \
# 3                   In-Hearing (Hearing Disabilities)              ...
# 4                     In-Speech (Speech Disabilities)              ...
# 0                     In-Seeing (Visual Disabilities)              ...
# 18                In-Movement (Mobility Disabilities)              ...
# 17                    In-Seeing (Visual Disabilities)              ...
#
#    11. Do you engage in reading outside of work or school?  \
# 3                                   Yes, occasionally
# 4                                   Yes, occasionally
# 0                                   Yes, occasionally
# 18                                         Yes, daily
# 17                                         Yes, daily
#
#    12. Do you receive food stamps or similar social welfare benefits?  \
# 3                                   Yes, occasionally
# 4                                   Yes, occasionally
# 0                                   Yes, occasionally
# 18                                                 No
# 17                              No, I am not eligible
#
#    13. How many times have you been hospitalized for mental illness?  \
# 3                                         3â€“5 times
# 4                                         1â€“2 times
# 0                                                 NaN
# 18                                                NaN
# 17                                                NaN
#
#    14. How often do you experience a lack of concentration?  \
# 3              Frequently, affecting daily activities
# 4                        Occasionally, but manageable
# 0                  Rarely, during high-stress periods
# 18                       Occasionally, but manageable
# 17                        Never / Not experienced yet
#
#                 15. Do you experience anxiety?  \
# 3   Frequently, requiring professional support
# 4                 Occasionally, but manageable
# 0                 Occasionally, but manageable
# 18                                      Rarely
# 17                    No / Not experienced yet
#
#        16. How often do you experience depression?  \
# 3      Frequently, requiring medication or therapy
# 4   Occasionally, but manageable without treatment
# 0                                           Rarely
# 18                  I do not experience depression
# 17                  I do not experience depression
#
#            17. Do you engage in obsessive thinking?  \
# 3   Yes, and it significantly impacts my daily life
# 4                         Yes, but it is manageable
# 0                           Rarely, not significant
# 18                                               No
# 17                                               No
#
#    18. How often do you experience mood swings?  \
# 3                                         Daily
# 4                                        Weekly
# 0                                       Monthly
# 18                                       Rarely
# 17                                        Never
#
#    19. Do you experience panic attacks?  \
# 3                       Yes, frequently
# 4                     Yes, occasionally
# 0                     Yes, occasionally
# 18                                   No
# 17                                   No
#
#    20. How often do you engage in compulsive behavior?
# 3          Frequently, requiring professional support
# 4                        Occasionally, but manageable
# 0                                              Rarely
# 18                                              Never
# 17                                    Not engaged yet
#
# [5 rows x 29 columns]

# %%
#Display renamed columns
df.head()
# Out:
#             Timestamp                                     Email  \
# 0  1/24/2025 18:11:32                    arickagarwal@gmail.com
# 1  1/28/2025 14:11:32  radhakrishnanrajan@onmyowntechnology.com
# 2  1/28/2025 14:13:31         surajsharma@onmyowntechnology.com
# 3  1/28/2025 14:17:21         priyamishra@onmyowntechnology.com
# 4  1/28/2025 14:19:23      kashishagarwal@onmyowntechnology.com
#
#   Name of the Participant Participant Age Range Participant gender  \
# 0           arick agarwal                  < 18               Male
# 1     Radhakrishnan Rajan               30 - 50               Male
# 2            Suraj Sharma               30 - 50               Male
# 3            Priya Mishra               19 - 30             Female
# 4         Kashish Agarwal               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  \
# 0            Technician                     1â€“5 years
# 1               Laborer                    6â€“10 years
# 2            Technician                     1â€“5 years
# 3            Technician                     1â€“5 years
# 4            Technician                     1â€“5 years
#
#   1. Which among the below categories best explains your status?  ...  \
# 0                    In-Seeing (Visual Disabilities)              ...
# 1                In-Movement (Mobility Disabilities)              ...
# 2     Mental Retardation (Intellectual Disabilities)              ...
# 3                  In-Hearing (Hearing Disabilities)              ...
# 4                    In-Speech (Speech Disabilities)              ...
#
#   11. Do you engage in reading outside of work or school?  \
# 0                                  Yes, occasionally
# 1                                             Rarely
# 2                                             Rarely
# 3                                  Yes, occasionally
# 4                                  Yes, occasionally
#
#   12. Do you receive food stamps or similar social welfare benefits?  \
# 0                                  Yes, occasionally
# 1                                  Yes, occasionally
# 2                              No, I am not eligible
# 3                                  Yes, occasionally
# 4                                  Yes, occasionally
#
#   13. How many times have you been hospitalized for mental illness?  \
# 0                                                NaN
# 1                                                NaN
# 2                                        1â€“2 times
# 3                                        3â€“5 times
# 4                                        1â€“2 times
#
#   14. How often do you experience a lack of concentration?  \
# 0                 Rarely, during high-stress periods
# 1                       Occasionally, but manageable
# 2                       Occasionally, but manageable
# 3             Frequently, affecting daily activities
# 4                       Occasionally, but manageable
#
#                15. Do you experience anxiety?  \
# 0                Occasionally, but manageable
# 1                Occasionally, but manageable
# 2                Occasionally, but manageable
# 3  Frequently, requiring professional support
# 4                Occasionally, but manageable
#
#       16. How often do you experience depression?  \
# 0                                          Rarely
# 1                                          Rarely
# 2  Occasionally, but manageable without treatment
# 3     Frequently, requiring medication or therapy
# 4  Occasionally, but manageable without treatment
#
#           17. Do you engage in obsessive thinking?  \
# 0                          Rarely, not significant
# 1                          Rarely, not significant
# 2                        Yes, but it is manageable
# 3  Yes, and it significantly impacts my daily life
# 4                        Yes, but it is manageable
#
#   18. How often do you experience mood swings?  \
# 0                                      Monthly
# 1                                      Monthly
# 2                                       Weekly
# 3                                        Daily
# 4                                       Weekly
#
#   19. Do you experience panic attacks?  \
# 0                    Yes, occasionally
# 1                    Yes, occasionally
# 2                    Yes, occasionally
# 3                      Yes, frequently
# 4                    Yes, occasionally
#
#   20. How often do you engage in compulsive behavior?
# 0                                             Rarely
# 1                       Occasionally, but manageable
# 2                       Occasionally, but manageable
# 3         Frequently, requiring professional support
# 4                       Occasionally, but manageable
#
# [5 rows x 29 columns]

# %%
# Function 9: Filter rows based on a condition
filter_condition = df['your_column_name'] > 10  # Replace with an actual condition
if 'your_column_name' in df.columns:
    filtered_df = df[filter_condition]
    print("\nFiltered DataFrame (rows where your_column_name > 10):")
    print(filtered_df.head())
else:
    print(f"\nColumn 'your_column_name' not found in the DataFrame.")
