# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/employement-arick-repo/blob/main/Vivo_Ignite_FINAL_Exploring_Indian_Disability_and_Employment_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EDA insights :  Exploring Indian Disability and Employment Data##Questionnaire for employees
#  **(1) Demographic and Employment Analysis**<br>
#  **(2) Mental Health and Employment Correlation**<br>
#  **(3) Financial and Social Welfare Insights**<br>
#  **(4) Workplace and Psychological Well-being**<br>
#
#  ### Author : Arick Agarwal

# %% [markdown]
# ##Github Clone

# %%
# !git clone https://github.com/radhakrishnan-omotec/employement-arick-repo.git
# Out:
# Cloning into 'employement-arick-repo'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 60 (delta 29), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 5.24 MiB | 6.79 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %% [markdown]
# # Step 1: Mount Google Drive

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Step 2: Specify the file path for the CSV file in your Google Drive

# %%
# Step 2: Specify the file path for the CSV file in your Google Drive
file_path = '/content/employement-arick-repo/FINAL---Questionnaire-Form-Responses.csv'

# %% [markdown]
# # Step 3: Import necessary libraries

# %%
# Step 3: Import necessary libraries
import pandas as pd

# %% [markdown]
# # Step 4: Load the CSV file into a Pandas DataFrame

# %%
# Step 4: Load the CSV file into a Pandas DataFrame
try:
    df = pd.read_csv(file_path)
    print("CSV file loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please check the file path.")
# Out:
# CSV file loaded successfully!

# %% [markdown]
# # Step 5: Display the first few rows of the DataFrame

# %%
# Step 5: Display the first few rows of the DataFrame
print("\nPreview of the DataFrame:")
print(df.head())
# Out:
# Preview of the DataFrame:
#             Timestamp                                     Email  \
# 0  1/24/2025 18:11:32                    arickagarwal@gmail.com
# 1  1/28/2025 14:11:32  radhakrishnanrajan@onmyowntechnology.com
# 2  1/28/2025 14:13:31         surajsharma@onmyowntechnology.com
# 3  1/28/2025 14:17:21         priyamishra@onmyowntechnology.com
# 4  1/28/2025 14:19:23      kashishagarwal@onmyowntechnology.com
#
#   Name of the Participant Participant Age Range Participant gender  \
# 0           arick agarwal                  < 18               Male
# 1     Radhakrishnan Rajan               30 - 50               Male
# 2            Suraj Sharma               30 - 50               Male
# 3            Priya Mishra               19 - 30             Female
# 4         Kashish Agarwal               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# ...

# %%
# Function 1: Display DataFrame information
print("\nDataFrame Information:")
df.info()
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 29 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Timestamp                                                                        500 non-null    object
#  1   Email                                                                            500 non-null    object
#  2   Name of the Participant                                                          500 non-null    object
#  3   Participant Age Range                                                            500 non-null    object
#  4   Participant gender                                                               500 non-null    object
# ...

# %%
# Function 2: Get statistical summary
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#                  Timestamp                   Email  \
# count                  500                     500
# unique                  20                     498
# top     1/30/2025 23:06:39  suman_pillay@gmail.com
# freq                   436                       2
#
#                      Name of the Participant Participant Age Range  \
# count                                    500                   500
# unique                                   499                     4
# top     Anand Iyer                                         19 - 30
# freq                                       2                   247
#
#        Participant gender Participant region of work  \
# count                 500                        500
# unique                  2                          2
# top                  Male                      Urban
# freq                  257                        390
#
#        Participant industry of work Participant  job role  \
# ...

# %%
# Function 3: Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Timestamp                                                                            0
# Email                                                                                0
# Name of the Participant                                                              0
# Participant Age Range                                                                0
# Participant gender                                                                   0
# Participant region of work                                                           0
# Participant industry of work                                                         0
# Participant  job role                                                                0
# Participant years of experience                                                      0
# 1. Which among the below categories best explains your status?                       6
# 2. Are you currently employed at least part-time?                                    0
# ...

# %%
# Function 4: Display column names
print("\nColumn Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Timestamp', 'Email', 'Name of the Participant',
#        'Participant Age Range', 'Participant gender',
#        'Participant region of work', 'Participant industry of work',
#        'Participant  job role', 'Participant years of experience',
#        '1. Which among the below categories best explains your status?',
#        '2. Are you currently employed at least part-time?',
#        '3. Do you identify as having a mental illness?',
#        '4. Do you have access to a personal computer separate from a smartphone?',
#        '5. Have you been hospitalised before for a mental illness?',
#        '6. If hospitalised for mental illness, how many days were you hospitalised?',
#        '7. Do you have regular access to the internet?',
#        '8. Have you experienced any gaps in your resume due to health or other reasons?',
#        '9. What is your monthly income, including any social welfare programs, in INR?',
#        '10. Are you currently unemployed?',
# ...

# %%
# Function 5: Display shape of the DataFrame
print("\nShape of the DataFrame (Rows, Columns):")
print(df.shape)
# Out:
# Shape of the DataFrame (Rows, Columns):
# (500, 29)

# %%
#Display renamed columns
df.head()
# Out:
#             Timestamp                                     Email  \
# 0  1/24/2025 18:11:32                    arickagarwal@gmail.com
# 1  1/28/2025 14:11:32  radhakrishnanrajan@onmyowntechnology.com
# 2  1/28/2025 14:13:31         surajsharma@onmyowntechnology.com
# 3  1/28/2025 14:17:21         priyamishra@onmyowntechnology.com
# 4  1/28/2025 14:19:23      kashishagarwal@onmyowntechnology.com
#
#   Name of the Participant Participant Age Range Participant gender  \
# 0           arick agarwal                  < 18               Male
# 1     Radhakrishnan Rajan               30 - 50               Male
# 2            Suraj Sharma               30 - 50               Male
# 3            Priya Mishra               19 - 30             Female
# 4         Kashish Agarwal               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# ...

# %%
df.describe()
# Out:
#                  Timestamp                   Email  \
# count                  500                     500
# unique                  20                     498
# top     1/30/2025 23:06:39  suman_pillay@gmail.com
# freq                   436                       2
#
#                      Name of the Participant Participant Age Range  \
# count                                    500                   500
# unique                                   499                     4
# top     Anand Iyer                                         19 - 30
# freq                                       2                   247
#
#        Participant gender Participant region of work  \
# count                 500                        500
# unique                  2                          2
# top                  Male                      Urban
# freq                  257                        390
#
#        Participant industry of work Participant  job role  \
# ...

# %% [markdown]
# ##STEP : Preprocessing Dataset

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_Age_group = LabelEncoder()
le_Gender = LabelEncoder()
le_Q1 = LabelEncoder()
le_Q2 = LabelEncoder()
le_Q3 = LabelEncoder()
le_Q4 = LabelEncoder()
le_Q5 = LabelEncoder()
le_Q6 = LabelEncoder()
le_Q7 = LabelEncoder()
le_Q8 = LabelEncoder()
le_Q9 = LabelEncoder()
le_Q10 = LabelEncoder()
le_Q11 = LabelEncoder()
le_Q12 = LabelEncoder()
le_Q13 = LabelEncoder()
le_Q14 = LabelEncoder()
le_Q15 = LabelEncoder()
le_Q16 = LabelEncoder()
le_Q17 = LabelEncoder()
le_Q18 = LabelEncoder()
le_Q19 = LabelEncoder()
le_Q20 = LabelEncoder()

# %% [markdown]
# **STEP : Age Range Preprocessing**<br>
# Age Range<br><br>
# < 18 ( Range 0)<br>
# 19 - 30 ( Range 1)<br>
# 30 - 50 ( Range 2)<br>
# 50 ( Range 3)

# %%
# Define the age ranges and labels
age_ranges = ["< 18", "19 - 30", "30 - 50", "> 50"]
age_labels = [0, 1, 2, 3]

# Map age_range values to age_labels
age_mapping = dict(zip(age_ranges, age_labels))
print(age_mapping)
print()
print(df["Participant Age Range"])
df['Age_group_new'] = df['Participant Age Range'].map(age_mapping)

# Display the DataFrame with age labels
print(df['Age_group_new'])
# Out:
# {'< 18': 0, '19 - 30': 1, '30 - 50': 2, '> 50': 3}
#
# 0         < 18
# 1      30 - 50
# 2      30 - 50
# 3      19 - 30
# 4      19 - 30
#         ...
# 495    19 - 30
# 496       < 18
# 497    30 - 50
# 498    30 - 50
# 499    19 - 30
# Name: Participant Age Range, Length: 500, dtype: object
# 0      0
# 1      2
# 2      2
# 3      1
# 4      1
#       ..
# 495    1
# 496    0
# 497    2
# 498    2
# 499    1
# Name: Age_group_new, Length: 500, dtype: int64

# %%
df.head()
# Out:
#             Timestamp                                     Email  \
# 0  1/24/2025 18:11:32                    arickagarwal@gmail.com
# 1  1/28/2025 14:11:32  radhakrishnanrajan@onmyowntechnology.com
# 2  1/28/2025 14:13:31         surajsharma@onmyowntechnology.com
# 3  1/28/2025 14:17:21         priyamishra@onmyowntechnology.com
# 4  1/28/2025 14:19:23      kashishagarwal@onmyowntechnology.com
#
#   Name of the Participant Participant Age Range Participant gender  \
# 0           arick agarwal                  < 18               Male
# 1     Radhakrishnan Rajan               30 - 50               Male
# 2            Suraj Sharma               30 - 50               Male
# 3            Priya Mishra               19 - 30             Female
# 4         Kashish Agarwal               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# ...

# %%
#df['Gender_new'] = le_Q1.fit_transform(df['Gender'])
df['Q1_new'] = le_Q1.fit_transform(df['1. Which among the below categories best explains your status?'])
df['Q2_new'] = le_Q2.fit_transform(df['2. Are you currently employed at least part-time?'])
df['Q3_new'] = le_Q3.fit_transform(df['3. Do you identify as having a mental illness?'])
df['Q4_new'] = le_Q4.fit_transform(df['4. Do you have access to a personal computer separate from a smartphone?'])
df['Q5_new'] = le_Q5.fit_transform(df['5. Have you been hospitalised before for a mental illness?'])
df['Q6_new'] = le_Q6.fit_transform(df['6. If hospitalised for mental illness, how many days were you hospitalised?'])
df['Q7_new'] = le_Q7.fit_transform(df['7. Do you have regular access to the internet?'])
df['Q8_new'] = le_Q8.fit_transform(df['8. Have you experienced any gaps in your resume due to health or other reasons?'])
df['Q9_new'] = le_Q9.fit_transform(df['9. What is your monthly income, including any social welfare programs, in INR?'])
df['Q10_new'] = le_Q10.fit_transform(df['10. Are you currently unemployed?'])
df['Q11_new'] = le_Q11.fit_transform(df['11. Do you engage in reading outside of work or school?'])
df['Q12_new'] = le_Q12.fit_transform(df['12. Do you receive food stamps or similar social welfare benefits?'])
df['Q13_new'] = le_Q13.fit_transform(df['13. How many times have you been hospitalized for mental illness?'])
df['Q14_new'] = le_Q13.fit_transform(df['14. How often do you experience a lack of concentration?'])
df['Q15_new'] = le_Q13.fit_transform(df['15. Do you experience anxiety?'])
df['Q16_new'] = le_Q13.fit_transform(df['16. How often do you experience depression?'])
df['Q17_new'] = le_Q13.fit_transform(df['17. Do you engage in obsessive thinking?'])
df['Q18_new'] = le_Q13.fit_transform(df['18. How often do you experience mood swings?'])
df['Q19_new'] = le_Q13.fit_transform(df['19. Do you experience panic attacks?'])
df['Q20_new'] = le_Q13.fit_transform(df['20. How often do you engage in compulsive behavior?'])

# %%
df.head()
# Out:
#             Timestamp                                     Email  \
# 0  1/24/2025 18:11:32                    arickagarwal@gmail.com
# 1  1/28/2025 14:11:32  radhakrishnanrajan@onmyowntechnology.com
# 2  1/28/2025 14:13:31         surajsharma@onmyowntechnology.com
# 3  1/28/2025 14:17:21         priyamishra@onmyowntechnology.com
# 4  1/28/2025 14:19:23      kashishagarwal@onmyowntechnology.com
#
#   Name of the Participant Participant Age Range Participant gender  \
# 0           arick agarwal                  < 18               Male
# 1     Radhakrishnan Rajan               30 - 50               Male
# 2            Suraj Sharma               30 - 50               Male
# 3            Priya Mishra               19 - 30             Female
# 4         Kashish Agarwal               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# ...

# %% [markdown]
# ### STEP: Dropping unwanted columns

# %%
### STEP: Dropping unwanted columns
# dropping unwanted columns

columns_to_drop = ['Timestamp','Email','Name of the Participant','1. Which among the below categories best explains your status?','2. Are you currently employed at least part-time?','3. Do you identify as having a mental illness?','4. Do you have access to a personal computer separate from a smartphone?','5. Have you been hospitalised before for a mental illness?','6. If hospitalised for mental illness, how many days were you hospitalised?','7. Do you have regular access to the internet?','8. Have you experienced any gaps in your resume due to health or other reasons?','9. What is your monthly income, including any social welfare programs, in INR?','10. Are you currently unemployed?','11. Do you engage in reading outside of work or school?','12. Do you receive food stamps or similar social welfare benefits?','13. How many times have you been hospitalized for mental illness?','14. How often do you experience a lack of concentration?','15. Do you experience anxiety?','16. How often do you experience depression?','17. Do you engage in obsessive thinking?','18. How often do you experience mood swings?','19. Do you experience panic attacks?','20. How often do you engage in compulsive behavior?']


new_input_df = df.drop(columns_to_drop, axis=1)
new_input_df.head(50)
# Out:
#    Participant Age Range Participant gender Participant region of work  \
# 0                   < 18               Male                      Urban
# 1                30 - 50               Male                      Rural
# 2                30 - 50               Male                      Urban
# 3                19 - 30             Female                      Urban
# 4                19 - 30             Female                      Rural
# 5                30 - 50               Male                      Urban
# 6                30 - 50               Male                      Urban
# 7                   > 50               Male                      Urban
# 8                30 - 50               Male                      Urban
# 9                19 - 30               Male                      Urban
# 10               30 - 50               Male                      Urban
# 11               30 - 50               Male                      Rural
# ...

# %% [markdown]
# ##STEP : Saving the dataframe

# %%
# saving the dataframe
new_input_df.to_csv('/content/employement-arick-repo/Final_Output_Responses_Final.csv')

# %% [markdown]
# ## Box plot:

# %%
# BOX PLOT PYTHON CODE SAMPLE -1

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read "Output Responses.CSV File"
data =  pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

data.head(1)

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Set up the figure and axes
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")

# Create the boxplot using Seaborn
sns.boxplot(data=df.iloc[:, 7:], palette="flare")  # Assuming the numerical columns start from index 10 # DEA Correction to the appropriate name


# Customize the plot
plt.title("Distribution of Responses") # DEA Correction to the appropriate name
plt.xticks(rotation=90)
plt.xlabel("Questions")
plt.ylabel("Response Value")

# Show the plot
plt.tight_layout()
plt.show()

# %%
# BOX PLOT PYTHON CODE SAMPLE -1

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read "Output Responses.CSV File"
data =  pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

data.head(1)

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Set up the figure and axes
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")

# Create the boxplot using Seaborn
sns.boxplot(data=df.iloc[:, 7:], palette="viridis")  # Assuming the numerical columns start from index 10 # DEA Correction to the appropriate name


# Customize the plot
plt.title("Distribution of Responses") # DEA Correction to the appropriate name
plt.xticks(rotation=90)
plt.xlabel("Questions")
plt.ylabel("Response Value")

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #BASIC INSIGHTS :: Exploratory Data Analysis
# ##INSIGHT based on individual variables
# ###'Age_group' BASED UNIVARIABLE ANALYSIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Age' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Age_group_new" column exists, generate pie chart for its value counts
if 'Age_group_new' in df.columns:
    # Count the occurrences of each value in the 'Age_group_new' column
    q1_counts = df['Age_group_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q1_counts, labels=q1_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q1_counts.index, title="Age_group", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Age_group')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q1_counts.nlargest(3).index
    sns.countplot(x='Age_group_new', data=df[df['Age_group_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Four Age Group ')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Age_group_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# # Q1 ::

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q1' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q1_new" column exists, generate pie chart for its value counts
if 'Q1_new' in df.columns:
    # Count the occurrences of each value in the 'Q1_new' column
    q1_counts = df['Q1_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q1_counts, labels=q1_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q1_counts.index, title="Q1", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q1')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q1_counts.nlargest(3).index
    sns.countplot(x='Q1_new', data=df[df['Q1_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q1')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q1_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# # Q2 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q2' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q2_new" column exists, generate pie chart for its value counts
if 'Q2_new' in df.columns:
    # Count the occurrences of each value in the 'Q2_new' column
    q2_counts = df['Q2_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q2_counts, labels=q2_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q2_counts.index, title="Q2", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q2')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q2_counts.nlargest(3).index
    sns.countplot(x='Q2_new', data=df[df['Q2_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q2')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q2_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# # Q3 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q3' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q3_new" column exists, generate pie chart for its value counts
if 'Q3_new' in df.columns:
    # Count the occurrences of each value in the 'Q3_new' column
    q3_counts = df['Q3_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q3_counts, labels=q3_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q3_counts.index, title="Q3", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q3')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q3_counts.nlargest(3).index
    sns.countplot(x='Q3_new', data=df[df['Q3_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q3')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q3_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# # Q4 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q4' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q4_new" column exists, generate pie chart for its value counts
if 'Q4_new' in df.columns:
    # Count the occurrences of each value in the 'Q4_new' column
    q4_counts = df['Q4_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q4_counts, labels=q4_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q4_counts.index, title="Q4", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q4')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q4_counts.nlargest(3).index
    sns.countplot(x='Q4_new', data=df[df['Q4_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q4')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q4_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# # Q5 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q5' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q5_new" column exists, generate pie chart for its value counts
if 'Q5_new' in df.columns:
    # Count the occurrences of each value in the 'Q5_new' column
    q5_counts = df['Q5_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q5_counts, labels=q5_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q5_counts.index, title="Q5", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q5')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q5_counts.nlargest(3).index
    sns.countplot(x='Q5_new', data=df[df['Q5_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q5')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q5_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q6 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q6' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q6_new" column exists, generate pie chart for its value counts
if 'Q6_new' in df.columns:
    # Count the occurrences of each value in the 'Q6_new' column
    q6_counts = df['Q6_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q6_counts, labels=q6_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q6_counts.index, title="Q6", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q6')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q6_counts.nlargest(3).index
    sns.countplot(x='Q6_new', data=df[df['Q6_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q6')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q6_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q7 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q7' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q7_new" column exists, generate pie chart for its value counts
if 'Q7_new' in df.columns:
    # Count the occurrences of each value in the 'Q7_new' column
    q7_counts = df['Q7_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q7_counts, labels=q7_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q7_counts.index, title="Q7", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q7')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q7_counts.nlargest(3).index
    sns.countplot(x='Q7_new', data=df[df['Q7_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q7')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q7_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q8 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q8' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q8_new" column exists, generate pie chart for its value counts
if 'Q8_new' in df.columns:
    # Count the occurrences of each value in the 'Q8_new' column
    q8_counts = df['Q8_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q8_counts, labels=q8_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q8_counts.index, title="Q8", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q8')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q8_counts.nlargest(3).index
    sns.countplot(x='Q8_new', data=df[df['Q8_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q8')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q8_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q9 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q9' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q9_new" column exists, generate pie chart for its value counts
if 'Q9_new' in df.columns:
    # Count the occurrences of each value in the 'Q9_new' column
    q9_counts = df['Q9_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q9_counts, labels=q9_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q9_counts.index, title="Q9", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q9')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q9_counts.nlargest(3).index
    sns.countplot(x='Q9_new', data=df[df['Q9_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q9')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q9_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q10 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q10' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q10_new" column exists, generate pie chart for its value counts
if 'Q10_new' in df.columns:
    # Count the occurrences of each value in the 'Q10_new' column
    q10_counts = df['Q10_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q10_counts, labels=q10_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q10_counts.index, title="Q10", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q10')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q10_counts.nlargest(3).index
    sns.countplot(x='Q10_new', data=df[df['Q10_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q10')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q10_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q11 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q11' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q11_new" column exists, generate pie chart for its value counts
if 'Q11_new' in df.columns:
    # Count the occurrences of each value in the 'Q11_new' column
    q11_counts = df['Q11_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q11_counts, labels=q11_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q11_counts.index, title="Q11", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q11')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q11_counts.nlargest(3).index
    sns.countplot(x='Q11_new', data=df[df['Q11_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q11')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q11_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q12 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q12' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q12_new" column exists, generate pie chart for its value counts
if 'Q12_new' in df.columns:
    # Count the occurrences of each value in the 'Q12_new' column
    q12_counts = df['Q12_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q12_counts, labels=q12_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q12_counts.index, title="Q12", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q12')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q12_counts.nlargest(3).index
    sns.countplot(x='Q12_new', data=df[df['Q12_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q12')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q12_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q13 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q13' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q13_new" column exists, generate pie chart for its value counts
if 'Q13_new' in df.columns:
    # Count the occurrences of each value in the 'Q13_new' column
    q13_counts = df['Q13_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q13_counts, labels=q13_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q13_counts.index, title="Q13", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q13')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q13_counts.nlargest(3).index
    sns.countplot(x='Q13_new', data=df[df['Q13_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q13')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q13_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q14 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q14' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q14_new" column exists, generate pie chart for its value counts
if 'Q14_new' in df.columns:
    # Count the occurrences of each value in the 'Q14_new' column
    q14_counts = df['Q14_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q14_counts, labels=q14_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q14_counts.index, title="Q14", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q14')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q14_counts.nlargest(3).index
    sns.countplot(x='Q14_new', data=df[df['Q14_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q14')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q14_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q15 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q15' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q15_new" column exists, generate pie chart for its value counts
if 'Q15_new' in df.columns:
    # Count the occurrences of each value in the 'Q15_new' column
    q15_counts = df['Q15_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q15_counts, labels=q15_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q15_counts.index, title="Q15", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q15')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q15_counts.nlargest(3).index
    sns.countplot(x='Q15_new', data=df[df['Q15_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q15')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q15_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q16 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q16' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q16_new" column exists, generate pie chart for its value counts
if 'Q16_new' in df.columns:
    # Count the occurrences of each value in the 'Q16_new' column
    q16_counts = df['Q16_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q16_counts, labels=q16_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q16_counts.index, title="Q16", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q16')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q16_counts.nlargest(3).index
    sns.countplot(x='Q16_new', data=df[df['Q16_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q16')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q16_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q17 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q17' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q17_new" column exists, generate pie chart for its value counts
if 'Q17_new' in df.columns:
    # Count the occurrences of each value in the 'Q17_new' column
    q17_counts = df['Q17_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q17_counts, labels=q17_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q17_counts.index, title="Q17", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q17')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q17_counts.nlargest(3).index
    sns.countplot(x='Q17_new', data=df[df['Q17_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q17')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q17_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q18 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q18' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q18_new" column exists, generate pie chart for its value counts
if 'Q18_new' in df.columns:
    # Count the occurrences of each value in the 'Q18_new' column
    q18_counts = df['Q18_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q18_counts, labels=q18_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q18_counts.index, title="Q18", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q18')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q18_counts.nlargest(3).index
    sns.countplot(x='Q18_new', data=df[df['Q18_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q18')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q18_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q19 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q19' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q19_new" column exists, generate pie chart for its value counts
if 'Q19_new' in df.columns:
    # Count the occurrences of each value in the 'Q19_new' column
    q19_counts = df['Q19_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q19_counts, labels=q19_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q19_counts.index, title="Q19", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q19')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q19_counts.nlargest(3).index
    sns.countplot(x='Q19_new', data=df[df['Q19_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q19')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q19_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #Q20 :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

############## 'Q20' BASED UNIVARIABLE ANALYSIS  ##############
# Assuming "Q20_new" column exists, generate pie chart for its value counts
if 'Q20_new' in df.columns:
    # Count the occurrences of each value in the 'Q20_new' column
    q20_counts = df['Q20_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q20_counts, labels=q20_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q20_counts.index, title="Q20", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('Q20')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q20_counts.nlargest(3).index
    sns.countplot(x='Q20_new', data=df[df['Q20_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='flare')
    ax[1].set_title('Count of Top Three Q20')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q20_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# -------------
# -------------
# -------------

# %% [markdown]
# #ADVANCED INSIGHT : Demographic and Employment Analysis
# (1,2) Employment Status vs. Disability Category – How different disability categories impact employment.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q1_new" and "Q2_new" columns exist
if 'Q1_new' in df.columns and 'Q2_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q1_new", hue="Q2_new", data=df, palette='flare')
    plt.title("How different disability categories impact employment")
    plt.xlabel("Employment Status")
    plt.ylabel("Disability Category")
    plt.legend(title="How different disability categories impact employment")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q1_new' and/or 'Q2_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Demographic and Employment Analysis
# (2,3) Employment Status vs. Mental Illness – The relationship between mental illness and employment opportunities.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q2_new" and "Q3_new" columns exist
if 'Q2_new' in df.columns and 'Q3_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q2_new", hue="Q3_new", data=df, palette='flare')
    plt.title("The relationship between mental illness and employment opportunities")
    plt.xlabel("Employment Status")
    plt.ylabel("Mental Illness")
    plt.legend(title="The relationship between mental illness and employment opportunities")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q2_new' and/or 'Q3_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Demographic and Employment Analysis
# (2,7) Employment Status vs. Access to Internet – Whether digital access influences job opportunities.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q2_new" and "Q7_new" columns exist
if 'Q2_new' in df.columns and 'Q7_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q2_new", hue="Q7_new", data=df, palette='flare')
    plt.title("Whether digital access influences job opportunities")
    plt.xlabel("Employment Status")
    plt.ylabel("Access to Internet")
    plt.legend(title="Whether digital access influences job opportunities")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q2_new' and/or 'Q7_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Demographic and Employment Analysis
# (2,4) Employment Status vs. Access to Personal Computer – Do people with a personal computer have better employment rates?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q2_new" and "Q4_new" columns exist
if 'Q2_new' in df.columns and 'Q4_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q2_new", hue="Q4_new", data=df, palette='flare')
    plt.title("Do people with a personal computer have better employment rates?")
    plt.xlabel("Employment Status")
    plt.ylabel("Access to Personal Computer")
    plt.legend(title="Do people with a personal computer have better employment rates?")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q2_new' and/or 'Q4_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Demographic and Employment Analysis
# (2,22) Employment Status vs. Gender – Gender-based employment disparities among disabled individuals.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q2_new" and "Q22_new" columns exist
if 'Q2_new' in df.columns and 'Q22_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q2_new", hue="Q22_new", data=df, palette='flare')
    plt.title("Gender-based employment disparities among disabled individuals")
    plt.xlabel("Employment Status")
    plt.ylabel("Gender")
    plt.legend(title="Gender-based employment disparities among disabled individuals")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q2_new' and/or 'Q22_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Demographic and Employment Analysis
# (2,24) Employment Status vs. Industry of Work – Identifying industries that hire disabled individuals.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q2_new" and "Q24_new" columns exist
if 'Q2_new' in df.columns and 'Q24_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q2_new", hue="Q24_new", data=df, palette='flare')
    plt.title("Identifying industries that hire disabled individuals")
    plt.xlabel("Employment Status")
    plt.ylabel("Industry of Work")
    plt.legend(title="Identifying industries that hire disabled individuals")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q2_new' and/or 'Q24_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Demographic and Employment Analysis
# (2,23) Employment Status vs. Region of Work – Comparing employment trends across different regions in India.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q2_new" and "Q23_new" columns exist
if 'Q2_new' in df.columns and 'Q23_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q2_new", hue="Q23_new", data=df, palette='flare')
    plt.title("Comparing employment trends across different regions in India")
    plt.xlabel("Employment Status")
    plt.ylabel("Region of Work")
    plt.legend(title="Comparing employment trends across different regions in India")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q2_new' and/or 'Q23_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Demographic and Employment Analysis
# (2,26) Employment Status vs. Years of Experience – The role of experience in securing employment.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q2_new" and "Q26_new" columns exist
if 'Q2_new' in df.columns and 'Q26_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q2_new", hue="Q26_new", data=df, palette='flare')
    plt.title("The role of experience in securing employment")
    plt.xlabel("Employment Status")
    plt.ylabel("Years of Experience")
    plt.legend(title="The role of experience in securing employment")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q2_new' and/or 'Q26_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# -------------
# -------------
# -------------

# %% [markdown]
# #ADVANCED INSIGHT : Mental Health and Employment Correlation
# (2,3) Employment Status vs. Mental Illness – The relationship between mental illness and employment opportunities.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q2_new" and "Q3_new" columns exist
if 'Q2_new' in df.columns and 'Q3_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q2_new", hue="Q3_new", data=df, palette='flare')
    plt.title("The relationship between mental illness and employment opportunities")
    plt.xlabel("Employment Status")
    plt.ylabel("Mental Illness")
    plt.legend(title="The relationship between mental illness and employment opportunities")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q2_new' and/or 'Q3_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Mental Health and Employment Correlation
# (3,8) Mental Illness vs. Gaps in Resume – Analyzing how mental illness contributes to career interruptions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q3_new" and "Q8_new" columns exist
if 'Q3_new' in df.columns and 'Q8_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q3_new", hue="Q8_new", data=df, palette='flare')
    plt.title("Analyzing how mental illness contributes to career interruptions")
    plt.xlabel("Mental Illness")
    plt.ylabel("Gaps in Resume")
    plt.legend(title="Analyzing how mental illness contributes to career interruptions")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q3_new' and/or 'Q8_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Mental Health and Employment Correlation
# (3,24) Mental Illness vs. Industry of Work – Which industries employ individuals with mental illnesses?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q3_new" and "Q24_new" columns exist
if 'Q3_new' in df.columns and 'Q24_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q3_new", hue="Q24_new", data=df, palette='flare')
    plt.title("Which industries employ individuals with mental illnesses?")
    plt.xlabel("Mental Illness")
    plt.ylabel("Industry of Work")
    plt.legend(title="Which industries employ individuals with mental illnesses?")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q3_new' and/or 'Q24_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Mental Health and Employment Correlation
# (3,9) Mental Illness vs. Monthly Income – Impact of mental illness on earning potential.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q3_new" and "Q9_new" columns exist
if 'Q3_new' in df.columns and 'Q9_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q3_new", hue="Q9_new", data=df, palette='flare')
    plt.title("Impact of mental illness on earning potential")
    plt.xlabel("Mental Illness")
    plt.ylabel("Monthly Income")
    plt.legend(title="Impact of mental illness on earning potential")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q3_new' and/or 'Q9_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Mental Health and Employment Correlation
# (3,22) Mental Illness vs. Gender – Gender-based differences in mental health challenges.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q3_new" and "Q22_new" columns exist
if 'Q3_new' in df.columns and 'Q22_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q3_new", hue="Q22_new", data=df, palette='flare')
    plt.title("Gender-based differences in mental health challenges")
    plt.xlabel("Mental Illness")
    plt.ylabel("Gender")
    plt.legend(title="Gender-based differences in mental health challenges")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q3_new' and/or 'Q22_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Mental Health and Employment Correlation
# (3,19) Mental Illness vs. Panic Attacks – Do people with mental illnesses experience more panic attacks?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q3_new" and "Q19_new" columns exist
if 'Q3_new' in df.columns and 'Q19_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q3_new", hue="Q19_new", data=df, palette='flare')
    plt.title("Do people with mental illnesses experience more panic attacks?")
    plt.xlabel("Mental Illness")
    plt.ylabel("Panic Attacks")
    plt.legend(title="Do people with mental illnesses experience more panic attacks?")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q3_new' and/or 'Q19_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Mental Health and Employment Correlation
# (3,17) Mental Illness vs. Obsessive Thinking – Understanding obsessive thinking patterns in mental illness.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q3_new" and "Q17_new" columns exist
if 'Q3_new' in df.columns and 'Q17_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q3_new", hue="Q17_new", data=df, palette='flare')
    plt.title("Understanding obsessive thinking patterns in mental illness")
    plt.xlabel("Mental Illness")
    plt.ylabel("Obsessive Thinking")
    plt.legend(title="Understanding obsessive thinking patterns in mental illness")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q3_new' and/or 'Q17_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Mental Health and Employment Correlation
# (3,16) Mental Illness vs. Depression – Correlating mental illness with frequent depression episodes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q3_new" and "Q16_new" columns exist
if 'Q3_new' in df.columns and 'Q16_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q3_new", hue="Q16_new", data=df, palette='flare')
    plt.title("Correlating mental illness with frequent depression episodes")
    plt.xlabel("Mental Illness")
    plt.ylabel("Depression")
    plt.legend(title="Correlating mental illness with frequent depression episodes")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q3_new' and/or 'Q16_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Mental Health and Employment Correlation
# (3,11) Mental Illness vs. Reading Habits – Does reading help in managing mental health challenges?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q3_new" and "Q11_new" columns exist
if 'Q3_new' in df.columns and 'Q11_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q3_new", hue="Q11_new", data=df, palette='flare')
    plt.title("Does reading help in managing mental health challenges?")
    plt.xlabel("Mental Illness")
    plt.ylabel("Reading Habits")
    plt.legend(title="Does reading help in managing mental health challenges?")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q3_new' and/or 'Q11_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# -------------
# -------------
# -------------

# %% [markdown]
# #ADVANCED INSIGHT : Financial and Social Welfare Insights
# (9,1) Monthly Income vs. Disability Category – Income disparities among different disability types.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q9_new" and "Q1_new" columns exist
if 'Q9_new' in df.columns and 'Q1_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q9_new", hue="Q1_new", data=df, palette='flare')
    plt.title("Income disparities among different disability types")
    plt.xlabel("Monthly Income")
    plt.ylabel("Disability Category")
    plt.legend(title="Income disparities among different disability types")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q9_new' and/or 'Q1_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Financial and Social Welfare Insights
# (9,2) Monthly Income vs. Employment Status – The income gap between employed and unemployed individuals.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q9_new" and "Q2_new" columns exist
if 'Q9_new' in df.columns and 'Q2_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q9_new", hue="Q2_new", data=df, palette='flare')
    plt.title("The income gap between employed and unemployed individuals")
    plt.xlabel("Monthly Income")
    plt.ylabel("Employment Status")
    plt.legend(title="The income gap between employed and unemployed individuals")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q9_new' and/or 'Q2_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Financial and Social Welfare Insights
# (9,24) Monthly Income vs. Industry of Work – High-earning industries for disabled individuals.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q9_new" and "Q24_new" columns exist
if 'Q9_new' in df.columns and 'Q24_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q9_new", hue="Q24_new", data=df, palette='flare')
    plt.title("High-earning industries for disabled individuals")
    plt.xlabel("Monthly Income")
    plt.ylabel("Industry of Work")
    plt.legend(title="High-earning industries for disabled individuals")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q9_new' and/or 'Q24_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Financial and Social Welfare Insights
# (9,12) Monthly Income vs. Food Stamps – How social welfare programs support low-income disabled individuals.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q9_new" and "Q12_new" columns exist
if 'Q9_new' in df.columns and 'Q12_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q9_new", hue="Q12_new", data=df, palette='flare')
    plt.title("How social welfare programs support low-income disabled individuals")
    plt.xlabel("Monthly Income")
    plt.ylabel("Food Stamps")
    plt.legend(title="How social welfare programs support low-income disabled individuals")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q9_new' and/or 'Q12_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Financial and Social Welfare Insights
# (9,25) Monthly Income vs. Job Role – Comparing earnings across job roles.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q9_new" and "Q25_new" columns exist
if 'Q9_new' in df.columns and 'Q25_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q9_new", hue="Q25_new", data=df, palette='flare')
    plt.title("Comparing earnings across job roles")
    plt.xlabel("Monthly Income")
    plt.ylabel("Job Role")
    plt.legend(title="Comparing earnings across job roles")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q9_new' and/or 'Q25_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Financial and Social Welfare Insights
# (9,23) Monthly Income vs. Region of Work – Regional differences in income levels.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q9_new" and "Q23_new" columns exist
if 'Q9_new' in df.columns and 'Q23_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q9_new", hue="Q23_new", data=df, palette='flare')
    plt.title("Regional differences in income levels")
    plt.xlabel("Monthly Income")
    plt.ylabel("Region of Work")
    plt.legend(title="Regional differences in income levels")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q9_new' and/or 'Q23_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Financial and Social Welfare Insights
# (9,26) Monthly Income vs. Years of Experience – The impact of experience on financial stability.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q9_new" and "Q26_new" columns exist
if 'Q9_new' in df.columns and 'Q26_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q9_new", hue="Q26_new", data=df, palette='flare')
    plt.title("The impact of experience on financial stability")
    plt.xlabel("Monthly Income")
    plt.ylabel("Years of Experience")
    plt.legend(title="The impact of experience on financial stability")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q9_new' and/or 'Q26_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# -------------
# -------------
# -------------

# %% [markdown]
# #ADVANCED INSIGHT : Workplace and Psychological Well-being
# (8,15) Gaps in Resume vs. Anxiety Levels – How career interruptions affect mental well-being.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q8_new" and "Q15_new" columns exist
if 'Q8_new' in df.columns and 'Q15_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q8_new", hue="Q15_new", data=df, palette='flare')
    plt.title("How career interruptions affect mental well-being?")
    plt.xlabel("Gaps in Resume")
    plt.ylabel("Anxiety Levels")
    plt.legend(title="How career interruptions affect mental well-being?")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q8_new' and/or 'Q15_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Workplace and Psychological Well-being
# (8,19) Gaps in Resume vs. Panic Attacks – Does employment instability lead to frequent panic attacks?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q8_new" and "Q19_new" columns exist
if 'Q8_new' in df.columns and 'Q19_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q8_new", hue="Q19_new", data=df, palette='flare')
    plt.title("Does employment instability lead to frequent panic attacks?")
    plt.xlabel("Gaps in Resume")
    plt.ylabel("Panic Attacks")
    plt.legend(title="Does employment instability lead to frequent panic attacks?")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q8_new' and/or 'Q19_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Workplace and Psychological Well-being
# (24,15) Industry of Work vs. Anxiety – Identifying high-stress industries for disabled individuals.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q24_new" and "Q15_new" columns exist
if 'Q24_new' in df.columns and 'Q15_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q24_new", hue="Q15_new", data=df, palette='flare')
    plt.title("Identifying high-stress industries for disabled individuals")
    plt.xlabel("Industry of Work")
    plt.ylabel("Anxiety")
    plt.legend(title="Identifying high-stress industries for disabled individuals")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q24_new' and/or 'Q15_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Workplace and Psychological Well-being
# (24,18) Industry of Work vs. Mood Swings – Job-related factors influencing emotional stability.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q24_new" and "Q18_new" columns exist
if 'Q24_new' in df.columns and 'Q18_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q24_new", hue="Q18_new", data=df, palette='flare')
    plt.title("Job-related factors influencing emotional stability")
    plt.xlabel("Industry of Work")
    plt.ylabel("Mood Swings")
    plt.legend(title="Job-related factors influencing emotional stability")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q24_new' and/or 'Q18_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Workplace and Psychological Well-being
# (23,16) Region of Work vs. Depression – Regional variations in workplace mental health.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q23_new" and "Q16_new" columns exist
if 'Q23_new' in df.columns and 'Q16_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q23_new", hue="Q16_new", data=df, palette='flare')
    plt.title("Regional variations in workplace mental health")
    plt.xlabel("Region of Work")
    plt.ylabel("Depression")
    plt.legend(title="Regional variations in workplace mental health")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q23_new' and/or 'Q16_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# #ADVANCED INSIGHT : Workplace and Psychological Well-being
# (25,20) Job Role vs. Compulsive Behavior – Does job responsibility influence mental health behaviors?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/employement-arick-repo/Final_Output_Responses_Final.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q25_new" and "Q20_new" columns exist
if 'Q25_new' in df.columns and 'Q20_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q25_new", hue="Q20_new", data=df, palette='flare')
    plt.title("Does job responsibility influence mental health behaviors?")
    plt.xlabel("Job Role")
    plt.ylabel("Compulsive Behavior")
    plt.legend(title="Does job responsibility influence mental health behaviors?")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        # ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
        #             ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
        #             textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q25_new' and/or 'Q20_new' not found in the CSV file.")
# Out:
#    Unnamed: 0 Participant Age Range Participant gender  \
# 0           0                  < 18               Male
# 1           1               30 - 50               Male
# 2           2               30 - 50               Male
# 3           3               19 - 30             Female
# 4           4               19 - 30             Female
#
#   Participant region of work Participant industry of work  \
# 0                      Urban                Manufacturing
# 1                      Rural                  Agriculture
# 2                      Urban                     Services
# 3                      Urban                     Services
# 4                      Rural                Manufacturing
#
#   Participant  job role Participant years of experience  Age_group_new  \
# 0            Technician                     1 - 5 years              0
# 1               Laborer                    6 - 10 years              2
# ...

# %% [markdown]
# -------------
# -------------
# -------------
